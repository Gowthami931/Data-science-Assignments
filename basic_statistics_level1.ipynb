# %% [markdown]
# Q8) Calculate Expected Value for the problem below
# a)The weights (X) of patients at a clinic (in pounds), are
# 108, 110, 123, 134, 135, 145, 167, 187, 199
# Assume one of the patients is chosen at random. What is the Expected Value of the Weight of that patient?

# %%
import numpy as np
data_frame=[108,110,123,134,135,145,167,187,199]
data_frame
import pandas as pd
data_frame1=pd.DataFrame(data_frame)
data_frame1
# Out:
#      0
# 0  108
# 1  110
# 2  123
# 3  134
# 4  135
# 5  145
# 6  167
# 7  187
# 8  199

# %%
data_frame1.columns=["weights"]
data_frame1
# Out:
#    weights
# 0      108
# 1      110
# 2      123
# 3      134
# 4      135
# 5      145
# 6      167
# 7      187
# 8      199

# %%
expected_weight=data_frame1["weights"].mean()
print("Expected value of the weight of the patient choosen at random:",expected_weight)
# Out:
# Expected value of the weight of the patient choosen at random: 145.33333333333334

# %% [markdown]
# Q9) Calculate Skewness, Kurtosis & draw inferences on the following data
#       Cars speed and distance

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-ce07f434-2b46-41b0-86eb-cbcb9596677d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce07f434-2b46-41b0-86eb-cbcb9596677d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Q9_a.csv")
df
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
df.shape
df.head()
df.info()
df.isnull().sum()#no null values#
df["speed"].hist()
df["speed"].skew()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   50 non-null     int64
#  1   speed   50 non-null     int64
#  2   dist    50 non-null     int64
# dtypes: int64(3)
# memory usage: 1.3 KB
# -0.11750986144663393

# %%
df["speed"].kurt()
# Out:
# -0.5089944204057617

# %%
df["dist"].hist()
df["dist"].skew()
# Out:
# 0.8068949601674215

# %%
df["dist"].kurt()
# Out:
# 0.4050525816795765

# %%
df["speed"].skew()
# Out:
# -0.11750986144663393

# %%
df["speed"].kurt()
# Out:
# -0.5089944204057617

# %%
df["dist"].skew()
# Out:
# 0.8068949601674215

# %%
df["dist"].kurt()
# Out:
# 0.4050525816795765

# %% [markdown]
# Q11)  Suppose we want to estimate the average weight of an adult male in    Mexico. We draw a random sample of 2,000 men from a population of 3,000,000 men and weigh them. We find that the average person in our sample weighs 200 pounds, and the standard deviation of the sample is 30 pounds. Calculate 94%,98%,96% confidence interval?

# %%
standard_diviation=30
from scipy.stats import norm
CI=norm.interval(0.94,sample_mean,standard_diviation)
CI
# Out:
# (203.57619175546247, 316.42380824453755)

# %%
CI=norm.interval(0.96,sample_mean,standard_diviation)
CI
# Out:
# (198.38753268104531, 321.61246731895466)

# %%
CI=norm.interval(0.98,sample_mean,standard_diviation)
CI
# Out:
# (190.2095637787748, 329.7904362212252)

# %% [markdown]
# Q12)  Below are the scores obtained by a student in tests
# 34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56
# 1)Find mean, median, variance, standard deviation.
# 2)What can we say about the student marks?

# %%
data=[34,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56]
import pandas as pd
data=pd.DataFrame(data)
data.mean()
# Out:
# 0    41.294118
# dtype: float64

# %%
data.median()
# Out:
# 0    41.0
# dtype: float64

# %%
data.var()
# Out:
# 0    25.470588
# dtype: float64

# %%
data.std()
# Out:
# 0    5.046839
# dtype: float64

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': '0'}>]], dtype=object)

# %% [markdown]
#  20.Calculate probability from the given dataset for the below cases
#
# Data _set: Cars.csv
# Calculate the probability of MPG  of Cars for the below cases.
#        MPG <- Cars$MPG
# a.P(MPG>38)
# b.P(MPG<40)
# c.    P (20<MPG<50)

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-33080bd3-b180-4493-909d-22eefb206266" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33080bd3-b180-4493-909d-22eefb206266">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Cars (1).csv")
df
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
MPG=df["MPG"]
probability_greater_than_38=len(MPG[MPG>38])/len(MPG)
probability_greater_than_40=len(MPG[MPG>40])/len(MPG)
probability_between_20_and_50=len(MPG[(MPG>20)&(MPG<50)])/len(MPG)

# %%
print("P(MPG>38):",probability_greater_than_38)
# Out:
# P(MPG>38): 0.4074074074074074

# %%
print("P(MPG>40):",probability_greater_than_40)
# Out:
# P(MPG>40): 0.24691358024691357

# %%
print("P(20<MPG<50):",probability_between_20_and_50)
# Out:
# P(20<MPG<50): 0.8518518518518519

# %% [markdown]
# 21) Check whether the data follows normal distribution
# a)Check whether the MPG of Cars follows Normal Distribution
#         Dataset: Cars.csv

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-58679694-c26d-4be6-9192-0c23aa528c5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-58679694-c26d-4be6-9192-0c23aa528c5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Cars (1).csv")
df
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# ..  ...        ...  ...         ...        ...
# 76  322  36.900000   50  169.598513  16.132947
# 77  238  19.197888  115  150.576579  37.923113
# 78  263  34.000000   50  151.598513  15.769625
# 79  295  19.833733  119  167.944460  39.423099
# 80  236  12.101263  107  139.840817  34.948615
#
# [81 rows x 5 columns]

# %%
MPG=df["MPG"]
import scipy.stats as stats
stats,p_value=stats.shapiro(MPG)
print("statistics:",stats)
# Out:
# statistics: 0.9779686331748962

# %%
print("probability values:",p_value)
# Out:
# probability values: 0.17639249563217163

# %%
if p_value<0.05:
  print("The data follows a normal distribution")
else:
  print("The data not follows a normal distribution")
# Out:
# The data not follows a normal distribution

# %% [markdown]
# b)Check Whether the Adipose Tissue (AT) and Waist Circumference(Waist)  from wc-at data set  follows Normal Distribution
#        Dataset: wc-at.csv

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-13788732-c578-4bd3-9e4c-c5a6a9977642" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13788732-c578-4bd3-9e4c-c5a6a9977642">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("wc-at.csv")
df
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
wt=df["Waist"]
wt
at=df["AT"]
at
import numpy as np
import scipy.stats as stats
stats,p_value=stats.shapiro(wt)
print("statistics:",stats)
print("probability values:",p_value)
if p_value<0.05:
  print("The data follows a normal distribution")
else:
  print("The data does not follows the normal distribution")
# Out:
# statistics: 0.9558579921722412
# probability values: 0.0011704873759299517
# The data follows a normal distribution

# %%
import scipy.stats as stats
stats,p_value=stats.shapiro(at)
print("statistics:",stats)
print("probability values:",p_value)
if p_value<0.05:
      print("The data follows a normal distribution")
else:
  print("The data does not follows the normal distribution")
# Out:
# statistics: 0.9523370862007141
# probability values: 0.0006539996829815209
# The data follows a normal distribution

# %%
import scipy.stats as stats
stats,p_value=stats.shapiro(at)
print("statistics:",stats)
print("probability values:",p_value)
if p_value<0.05:
      print("The data follows a normal distribution")
else:
  print("The data does not follows the normal distribution")
# Out:
# statistics: 0.9523370862007141
# probability values: 0.0006539996829815209
# The data follows a normal distribution

# %% [markdown]
#  22) Calculate the Z scores of  90% confidence interval,94% confidence interval, 60% confidence interval

# %%
import pandas as pd
import scipy.stats as stats
Z_critical=stats.norm.ppf((1+0.90)/2)
Z_critical
# Out:
# 1.6448536269514722

# %%
Z_critical=stats.norm.ppf((1+0.94)/2)
Z_critical
# Out:
# 1.8807936081512509

# %%
Z_critical=stats.norm.ppf((1+0.60)/2)
Z_critical
# Out:
# 0.8416212335729143

# %% [markdown]
#  23) Calculate the t scores of 95% confidence interval, 96% confidence interval, 99% confidence interval for sample size of 25

# %%
sample_size=25
df=sample_size-1
df
# Out:
# 24

# %%
import scipy.stats as stats
t_score=stats.t.ppf((1+0.95)/2,df)
t_score
# Out:
# 2.0638985616280205

# %%
t_score=stats.t.ppf((1+0.96)/2,df)
t_score
# Out:
# 2.1715446760080677

# %%
t_score=stats.t.ppf((1+0.99)/2,df)
t_score
# Out:
# 2.796939504772804

# %% [markdown]
# 24)   A Government  company claims that an average light bulb lasts 270 days. A researcher randomly selects 18 bulbs for testing. The sampled bulbs last an average of 260 days, with a standard deviation of 90 days. If the CEO's claim were true, what is the probability that 18 randomly selected bulbs would have an average life of no more than 260 days
# Hint:
#    rcode   pt(tscore,df)
#  df  degrees of freedom

# %%
mean=270
sample_mean=260
sample_size=18
standard_deviation=90
df=sample_size-1
df
# Out:
# 17

# %%
standard_error=standard_deviation/(sample_size**0.5)
standard_error
# Out:
# 21.213203435596427

# %%
t_statistics=(sample_mean-mean)/standard_deviation
t_statistics
# Out:
# -0.1111111111111111

# %%
import scipy.stats as stats
p_value=stats.t.cdf(t_statistics,df)
p_value
# Out:
# 0.4564147646595417
