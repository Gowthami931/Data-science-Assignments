# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-ac0b181c-18f4-4439-b170-80d672589452" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac0b181c-18f4-4439-b170-80d672589452">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("50_Startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
list(df)
# Out:
# ['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit']

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df1=df[["R&D Spend","Administration","Marketing Spend","State","Profit"]]
df1
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
# Standardization
from sklearn.preprocessing import MinMaxScaler
MM = MinMaxScaler()
df1["Profit"] =pd.DataFrame(MM.fit_transform(df1[["Profit"]]))
df1["Profit"]
# Out:
# 0     1.000000
# 1     0.997355
# 2     0.993178
# 3     0.947292
# 4     0.853171
# 5     0.801382
# 6     0.796490
# 7     0.794407
# 8     0.774468
# 9     0.760661
# 10    0.740175
# 11    0.729686
# 12    0.714629
# 13    0.673644
# 14    0.664044
# 15    0.648921
# 16    0.632454
# 17    0.623317
# 18    0.617103
# 19    0.608713
# 20    0.584482
# 21    0.544157
# 22    0.538747
# 23    0.529634
# 24    0.528609
# 25    0.522146
# 26    0.512737
# 27    0.508654
# 28    0.498934
# 29    0.486108
# 30    0.480099
# 31    0.466280
# 32    0.465966
# 33    0.462312
# 34    0.461939
# 35    0.460626
# 36    0.428126
# 37    0.423852
# 38    0.374747
# 39    0.373489
# 40    0.357914
# 41    0.355430
# 42    0.319951
# 43    0.310156
# 44    0.284485
# 45    0.282940
# 46    0.196020
# 47    0.156990
# 48    0.118211
# 49    0.000000
# Name: Profit, dtype: float64

# %%
df1.corr()
# Out:
# <ipython-input-9-49b3fcfeb4d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns
sns.set_style(style="darkgrid")
sns.pairplot(df1)

# %%
# Split the variables X and Y
Y = df1['Profit']
#X =df1[['R&D Spend']]
#X =df1['R&D Spend','Administration',]]
X =df1[['R&D Spend','Administration','Marketing Spend']]
#X =df1[['R&D Spend','Administration','Marketing Spend','State',]]                     ### Best model fit

# %%
Y
# Out:
# 0     1.000000
# 1     0.997355
# 2     0.993178
# 3     0.947292
# 4     0.853171
# 5     0.801382
# 6     0.796490
# 7     0.794407
# 8     0.774468
# 9     0.760661
# 10    0.740175
# 11    0.729686
# 12    0.714629
# 13    0.673644
# 14    0.664044
# 15    0.648921
# 16    0.632454
# 17    0.623317
# 18    0.617103
# 19    0.608713
# 20    0.584482
# 21    0.544157
# 22    0.538747
# 23    0.529634
# 24    0.528609
# 25    0.522146
# 26    0.512737
# 27    0.508654
# 28    0.498934
# 29    0.486108
# 30    0.480099
# 31    0.466280
# 32    0.465966
# 33    0.462312
# 34    0.461939
# 35    0.460626
# 36    0.428126
# 37    0.423852
# 38    0.374747
# 39    0.373489
# 40    0.357914
# 41    0.355430
# 42    0.319951
# 43    0.310156
# 44    0.284485
# 45    0.282940
# 46    0.196020
# 47    0.156990
# 48    0.118211
# 49    0.000000
# Name: Profit, dtype: float64

# %%
X
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# ...

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(X,Y)
# Out:
# LinearRegression()

# %%
LR.coef_
# Out:
# array([ 4.53718380e-06, -1.51007453e-07,  1.53328071e-07])

# %%
LR.intercept_
# Out:
# 0.1995760061503693

# %%
Y_pred=LR.predict(X)
Y_pred
# Out:
# array([1.00146088, 0.98251462, 0.94304242, 0.89545509, 0.88668619,
#        0.83848981, 0.80770554, 0.81844583, 0.77182097, 0.7895199 ,
#        0.68041065, 0.68077498, 0.64453417, 0.63524225, 0.75947134,
#        0.74081226, 0.57570536, 0.65047172, 0.64383686, 0.56849629,
#        0.57415262, 0.57798065, 0.56326917, 0.53674391, 0.55570068,
#        0.49305166, 0.54014497, 0.56158593, 0.48979849, 0.49055847,
#        0.47736664, 0.4674302 , 0.4748267 , 0.46870935, 0.41872786,
#        0.4270189 , 0.34128071, 0.42199547, 0.30980909, 0.38882444,
#        0.33863278, 0.33855733, 0.31500662, 0.25614106, 0.28116812,
#        0.18565813, 0.23361137, 0.17912553, 0.19422179, 0.18883688])

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(Y,Y_pred)
print("mean squared error:",np.sqrt(mse).round(4))
print("root mean squared value:",np.sqrt(mse).round(4))
# Out:
# mean squared error: 0.0499
# root mean squared value: 0.0499

# %%
from sklearn.metrics import r2_score
r2=r2_score(Y,Y_pred)
print("r2_scor:",r2.round(3))
# Out:
# r2_scor: 0.951

# %%
#improving the model by dats cleaning

import statsmodels.api as sm
model = sm.OLS(Y,X)
model = model.fit()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X1 = df1[['R&D Spend','Administration','Marketing Spend']]
vif = [variance_inflation_factor(X1.values, i) for i in range (X1.shape[1])]
vif
# Out:
# [8.384570754559961, 4.026405517894552, 7.593983592680924]

# %%
# residual analysis by using Q-Q plot

import matplotlib.pyplot as plt

QQ_plot = sm.qqplot(model.resid,line="q")
plt.title("normal Q-Q plot of reiduals")
plt.show()

# %%
list(np.where(model.resid>10))
# Out:
# [array([], dtype=int64)]

# %%
# residual plot for hooscedasticity
model.fittedvalues
model.resid
# Out:
# 0    -0.040575
# 1    -0.039574
# 2     0.071298
# 3     0.050503
# 4     0.006594
# 5    -0.011741
# 6    -0.000327
# 7    -0.055224
# 8    -0.033765
# 9    -0.006325
# 10    0.088699
# 11    0.099451
# 12    0.068082
# 13    0.023577
# 14   -0.131043
# 15   -0.082657
# 16    0.054101
# 17   -0.061119
# 18   -0.020794
# 19    0.053293
# 20    0.010470
# 21   -0.089503
# 22   -0.038775
# 23    0.000103
# 24    0.028505
# 25    0.024089
# 26   -0.034299
# 27   -0.085929
# 28   -0.051878
# 29   -0.021409
# 30    0.040795
# 31   -0.015065
# 32    0.020385
# 33    0.020133
# 34   -0.009711
# 35    0.084242
# 36    0.073079
# 37    0.101331
# 38    0.137955
# 39    0.042288
# 40    0.023759
# 41    0.070632
# 42    0.044619
# 43    0.071423
# 44   -0.014079
# 45    0.121538
# 46   -0.066050
# 47   -0.013727
# 48    0.050715
# 49   -0.164278
# dtype: float64

# %%
plt.scatter(model.fittedvalues,model.resid)
plt.title("residual plot")
plt.xlabel("Fitted values")
plt.ylabel("rsidual value")
plt.show()

# %%
# model delection diagnotics
# detecting influence\outliers
# cook's distance

model_influence = model.get_influence()
(cooks , P_value) = model_influence.cooks_distance
(cooks , P_value)
# Out:
# (array([1.67389164e-02, 1.24245218e-02, 5.11837947e-02, 1.72024182e-02,
#         3.64191931e-04, 8.61000908e-04, 2.04023892e-06, 1.20943423e-02,
#         3.69281874e-03, 1.70404503e-04, 2.02715662e-02, 2.62240298e-02,
#         9.07580618e-03, 1.12953302e-03, 6.96428657e-02, 2.22916843e-02,
#         6.30100844e-03, 9.06238877e-03, 1.07804092e-03, 5.86951641e-02,
#         3.64546212e-04, 3.21251950e-02, 5.72706637e-03, 4.80988228e-08,
#         1.69567412e-03, 1.70056381e-03, 4.40438724e-03, 5.43330057e-02,
#         2.01821159e-02, 2.26901011e-03, 4.94448870e-03, 1.27121561e-03,
#         2.65301804e-03, 7.46306418e-04, 5.22947285e-04, 1.40281210e-02,
#         3.15113230e-02, 1.91102404e-02, 7.31739667e-02, 2.89158041e-03,
#         2.32922503e-03, 1.17392286e-02, 5.57225944e-03, 2.80244020e-02,
#         1.76483905e-03, 1.05712956e-01, 1.30924634e-01, 1.69419350e-03,
#         2.79444441e-03, 1.60627147e-01]),
# ...

# %%
import numpy as np

# %%
#plot the influence values using the stemplot
fig = plt.subplots(figsize=(20,7))
plt.stem(np.arange(len(df1)),np.round(cooks,3))
plt.xlabel("Row index")
plt.ylabel("Cooks dis")
plt.show()

# %%
#index and value of influencer where c is more than 0.5
(np.argmax(cooks),np.max(cooks))
# Out:
# (49, 0.16062714739398884)

# %%
# high influence points

from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
from statsmodels.stats.outliers_influence import OLSInfluence
influence = model.get_influence()
threshold = 2.0
influence_summary = influence.summary_frame()
high_influence_points = influence_summary[influence_summary['hat_diag'] > threshold]
high_influence_indices = high_influence_points.index
high_influence_indices
# Out:
# Int64Index([], dtype='int64')

# %%
# Removing influencer points
df1[df1.index.isin([109])]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
df1_new = df1
df1_new
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 0   165349.20       136897.80        471784.10    New York  1.000000
# 1   162597.70       151377.59        443898.53  California  0.997355
# 2   153441.51       101145.55        407934.54     Florida  0.993178
# 3   144372.41       118671.85        383199.62    New York  0.947292
# 4   142107.34        91391.77        366168.42     Florida  0.853171
# 5   131876.90        99814.71        362861.36    New York  0.801382
# 6   134615.46       147198.87        127716.82  California  0.796490
# 7   130298.13       145530.06        323876.68     Florida  0.794407
# 8   120542.52       148718.95        311613.29    New York  0.774468
# 9   123334.88       108679.17        304981.62  California  0.760661
# 10  101913.08       110594.11        229160.95     Florida  0.740175
# 11  100671.96        91790.61        249744.55  California  0.729686
# 12   93863.75       127320.38        249839.44     Florida  0.714629
# ...

# %%
df1_new =df1_new.drop(["Marketing Spend"],axis=1)    #Drop HP Having high collinearity
df1_new
# Out:
#     R&D Spend  Administration       State    Profit
# 0   165349.20       136897.80    New York  1.000000
# 1   162597.70       151377.59  California  0.997355
# 2   153441.51       101145.55     Florida  0.993178
# 3   144372.41       118671.85    New York  0.947292
# 4   142107.34        91391.77     Florida  0.853171
# 5   131876.90        99814.71    New York  0.801382
# 6   134615.46       147198.87  California  0.796490
# 7   130298.13       145530.06     Florida  0.794407
# 8   120542.52       148718.95    New York  0.774468
# 9   123334.88       108679.17  California  0.760661
# 10  101913.08       110594.11     Florida  0.740175
# 11  100671.96        91790.61  California  0.729686
# 12   93863.75       127320.38     Florida  0.714629
# 13   91992.39       135495.07  California  0.673644
# 14  119943.24       156547.42     Florida  0.664044
# 15  114523.61       122616.84    New York  0.648921
# 16   78013.11       121597.55  California  0.632454
# ...

# %%
df1_new = df1_new.drop(df1_new.index[[49]],axis=0).reset_index()
df1_new                   # High influence points
# Out:
#     index  R&D Spend  Administration       State    Profit
# 0       0  165349.20       136897.80    New York  1.000000
# 1       1  162597.70       151377.59  California  0.997355
# 2       2  153441.51       101145.55     Florida  0.993178
# 3       3  144372.41       118671.85    New York  0.947292
# 4       4  142107.34        91391.77     Florida  0.853171
# 5       5  131876.90        99814.71    New York  0.801382
# 6       6  134615.46       147198.87  California  0.796490
# 7       7  130298.13       145530.06     Florida  0.794407
# 8       8  120542.52       148718.95    New York  0.774468
# 9       9  123334.88       108679.17  California  0.760661
# 10     10  101913.08       110594.11     Florida  0.740175
# 11     11  100671.96        91790.61  California  0.729686
# 12     12   93863.75       127320.38     Florida  0.714629
# 13     13   91992.39       135495.07  California  0.673644
# 14     14  119943.24       156547.42     Florida  0.664044
# ...

# %%
df1_new =df1_new.drop([""],axis=1)    #Drop newly created index column
df1_new

# %%
# Split the variables X and Y
Y = df1['Profit']
#X =df1[['R&D Spend']]
#X =df1['R&D Spend','Administration',]]
X =df1[['R&D Spend','Administration','Marketing Spend']]

# %%
X
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0   165349.20       136897.80        471784.10
# 1   162597.70       151377.59        443898.53
# 2   153441.51       101145.55        407934.54
# 3   144372.41       118671.85        383199.62
# 4   142107.34        91391.77        366168.42
# 5   131876.90        99814.71        362861.36
# 6   134615.46       147198.87        127716.82
# 7   130298.13       145530.06        323876.68
# 8   120542.52       148718.95        311613.29
# 9   123334.88       108679.17        304981.62
# 10  101913.08       110594.11        229160.95
# 11  100671.96        91790.61        249744.55
# 12   93863.75       127320.38        249839.44
# 13   91992.39       135495.07        252664.93
# 14  119943.24       156547.42        256512.92
# 15  114523.61       122616.84        261776.23
# 16   78013.11       121597.55        264346.06
# 17   94657.16       145077.58        282574.31
# 18   91749.16       114175.79        294919.57
# ...

# %%
Y
# Out:
# 0     1.000000
# 1     0.997355
# 2     0.993178
# 3     0.947292
# 4     0.853171
# 5     0.801382
# 6     0.796490
# 7     0.794407
# 8     0.774468
# 9     0.760661
# 10    0.740175
# 11    0.729686
# 12    0.714629
# 13    0.673644
# 14    0.664044
# 15    0.648921
# 16    0.632454
# 17    0.623317
# 18    0.617103
# 19    0.608713
# 20    0.584482
# 21    0.544157
# 22    0.538747
# 23    0.529634
# 24    0.528609
# 25    0.522146
# 26    0.512737
# 27    0.508654
# 28    0.498934
# 29    0.486108
# 30    0.480099
# 31    0.466280
# 32    0.465966
# 33    0.462312
# 34    0.461939
# 35    0.460626
# 36    0.428126
# 37    0.423852
# 38    0.374747
# 39    0.373489
# 40    0.357914
# 41    0.355430
# 42    0.319951
# 43    0.310156
# 44    0.284485
# 45    0.282940
# 46    0.196020
# 47    0.156990
# 48    0.118211
# 49    0.000000
# Name: Profit, dtype: float64

# %%
# Model fitting

from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X,Y)
# Out:
# LinearRegression()

# %%
# Model predicted values
y_pred = LR.predict(X)
y_pred
# Out:
# array([1.00146088, 0.98251462, 0.94304242, 0.89545509, 0.88668619,
#        0.83848981, 0.80770554, 0.81844583, 0.77182097, 0.7895199 ,
#        0.68041065, 0.68077498, 0.64453417, 0.63524225, 0.75947134,
#        0.74081226, 0.57570536, 0.65047172, 0.64383686, 0.56849629,
#        0.57415262, 0.57798065, 0.56326917, 0.53674391, 0.55570068,
#        0.49305166, 0.54014497, 0.56158593, 0.48979849, 0.49055847,
#        0.47736664, 0.4674302 , 0.4748267 , 0.46870935, 0.41872786,
#        0.4270189 , 0.34128071, 0.42199547, 0.30980909, 0.38882444,
#        0.33863278, 0.33855733, 0.31500662, 0.25614106, 0.28116812,
#        0.18565813, 0.23361137, 0.17912553, 0.19422179, 0.18883688])

# %%
# Model evaluation

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y,y_pred)
print("Mean square error ",mse.round(3))
# Out:
# Mean square error  0.002

# %%
import numpy as np
print("Root mean square error ", np.sqrt(mse).round(3))
# Out:
# Root mean square error  0.05

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y,y_pred)
print("r2_score",r2.round(3))
# Out:
# r2_score 0.951
